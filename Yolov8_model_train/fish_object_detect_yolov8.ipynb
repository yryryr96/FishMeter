# %%
# DataSet Download
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="sewmEnTxrguZRzUQxRra")
# project = rf.workspace("baesung-koo-wzsdb").project("fish-detection-mv7xg")
# dataset = project.version(1).download("yolov8")

from roboflow import Roboflow
rf = Roboflow(api_key="sewmEnTxrguZRzUQxRra")
project = rf.workspace("baesung-koo-wzsdb").project("fish-detection-team")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.141, to fix: `pip install ultralytics==8.0.134`
# ...
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ...
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ...
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# ...

# %%
import yaml

data = {'train':'C:/Users/SSAFY/Desktop/fish/Fish-Detection-team-1/train/images/',
        'val':'C:/Users/SSAFY/Desktop/fish/Fish-Detection-team-1/valid/images/',
        'test':'C:/Users/SSAFY/Desktop/fish/Fish-Detection-team-1/test/images',
        'names':['leopard mandarin fish', 'Fat greenling', 'black porgy', 'Red tilefish', 'Red Seabream', 'trout', 'Doldom', 'Black scraper'],
        'nc':8}

with open('C:/Users/SSAFY/Desktop/fish/Fish-Detection-team-1/Fish_Data.yaml', 'w') as f:
  yaml.dump(data, f)

with open('C:/Users/SSAFY/Desktop/fish/Fish-Detection-team-1/Fish_Data.yaml', 'r') as f:
  fish_yaml = yaml.safe_load(f)
  display(fish_yaml)
# Out:
# {'names': ['leopard mandarin fish',
#   'Fat greenling',
#   'black porgy',
#   'Red tilefish',
#   'Red Seabream',
#   'trout',
#   'Doldom',
#   'Black scraper'],
#  'nc': 8,
#  'test': 'C:/Users/SSAFY/Desktop/fish/Fish-Detection-team-1/test/images',
#  'train': 'C:/Users/SSAFY/Desktop/fish/Fish-Detection-team-1/train/images/',
#  'val': 'C:/Users/SSAFY/Desktop/fish/Fish-Detection-team-1/valid/images/'}

# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.141  Python-3.8.17 torch-1.7.1 CUDA:0 (GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
# Setup complete  (12 CPUs, 31.7 GB RAM, 205.8/953.2 GB disk)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %%
model.train(data='C:/Users/SSAFY/Desktop/fish/Fish-Detection-team-1/Fish_Data.yaml', epochs=150, patience=30, batch=32, imgsz=416)
# Out:
# New https://pypi.org/project/ultralytics/8.0.146 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.141  Python-3.8.17 torch-1.7.1 CUDA:0 (GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
# WARNING  Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 8
# {0: 'Fat greenling', 1: 'black porgy', 2: 'black scraper', 3: 'doldome', 4: 'leopard mandarin fish', 5: 'red seabream', 6: 'red tilefish', 7: 'trout'}

# %%
results = model.predict(source='C:/Users/SSAFY/Desktop/fish/Fish-Detection-team-1/test/images/', save=True)
# Out:
# image 1/156 C:\Users\SSAFY\Desktop\fish\Fish-Detection-team-1\test\images\-10-_jpg.rf.4e5c6b3a5f3b9bfb736495c5ed228098.jpg: 416x416 1 red tilefish, 0.0ms
# image 2/156 C:\Users\SSAFY\Desktop\fish\Fish-Detection-team-1\test\images\-12-_jpg.rf.6aa6276af747d09403196d598ade2bd7.jpg: 416x416 1 leopard mandarin fish, 9.2ms
# image 3/156 C:\Users\SSAFY\Desktop\fish\Fish-Detection-team-1\test\images\-14-_jpg.rf.57abe21e1251939f69cf47c5312ff408.jpg: 416x416 1 leopard mandarin fish, 0.0ms
# image 4/156 C:\Users\SSAFY\Desktop\fish\Fish-Detection-team-1\test\images\-14-_png.rf.a384beab1bb76e80dff0f89351de268d.jpg: 416x416 1 leopard mandarin fish, 10.5ms
# image 5/156 C:\Users\SSAFY\Desktop\fish\Fish-Detection-team-1\test\images\-15-_jpg.rf.ac2919b835aaa3077a9ed9a4b50a89c4.jpg: 416x416 1 Fat greenling, 9.0ms
# image 6/156 C:\Users\SSAFY\Desktop\fish\Fish-Detection-team-1\test\images\-17-_jpg.rf.f44e9f2e5f3ffaefc943d567a5fa52f6.jpg: 416x416 1 Fat greenling, 18.1ms
# ...

# %%
from ultralytics import YOLO
model = YOLO('C:/Users/SSAFY/Desktop/fish/runs/detect/train12/weights/best.pt')
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.141  Python-3.8.17 torch-1.7.1 CPU (11th Gen Intel Core(TM) i7-11600H 2.90GHz)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients
#
# PyTorch: starting from 'C:\Users\SSAFY\Desktop\fish\runs\detect\train12\weights\best.pt' with input shape (1, 3, 416, 416) BCHW and output shape(s) (1, 7, 3549) (5.9 MB)
#
# ONNX: starting export with onnx 1.14.0 opset 11...
# ONNX: export failure  0.3s: Exporting the operator silu to ONNX opset version 11 is not supported. Please open a bug to request ONNX export support for the missing operator.
# []
